# %%
import math
import numpy as np

import cv2 as cv

import matplotlib.pyplot as plt

# %%
from src.load_images import set_database, get_dataset_path
from src.show_images import show_img, show_imgs

# %%
set_database("custom")

# %%
img = cv.imread(get_dataset_path("cat.jpg"))
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img.shape
# Out:
# (427, 640, 3)

# %%
# https://www.youtube.com/watch?v=oXlwWbU8l2o&t=786s

# %%
show_img(img)
